# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 2
#       1 import pandas as pd
# ----> 2 import palmer_penguins
#
# ModuleNotFoundError: No module named 'palmer_penguins'

# %%
df = pd.read_csv('data/wetlands_seasonal_bird_diversity.csv')

# %%
df.head()
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x='year', y='CSM_winter')
# Out:
# <Axes: xlabel='year'>

# %%
df.plot(x='year', 
        y='CSM_winter',
        title='Bird species registered during winter at Carpinteria Salt Marsh',
        xlabel='Year',
        ylabel='Number of bird species',
        color='green',
        legend=False
        )
# Out:
# <Axes: title={'center': 'Bird species registered during winter at Carpinteria Salt Marsh'}, xlabel='Year', ylabel='Number of bird species'>

# %%
# df['MUL_spring'] == 

na_df = df.isna()
na_df
na_df[na_df["MUL_spring"] == True]
# Out:
#      year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0   False       False       False     False       False        True     False
# 10  False       False        True     False       False        True     False
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         True       False     False        True        True     False
# 10       False        True     False       False       False     False

# %%
df[df.isna()["MUL_spring"] == True]
# Out:
#     year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0   2010        39.0        40.0      50.0        45.0         NaN      61.0
# 10  2020        46.0         NaN      47.0        56.0         NaN      66.0
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0          NaN        75.0      85.0         NaN         NaN      81.0
# 10        57.0         NaN      58.0        54.0        40.0      54.0

# %%
df.plot(x='year', 
        y='MUL_spring',
        title='Bird species registered during spring at Mugu Lagoon',
        xlabel='Year',
        ylabel='Number of bird species',
        color='green',
        legend=False
        )
# Out:
# <Axes: title={'center': 'Bird species registered during spring at Mugu Lagoon'}, xlabel='Year', ylabel='Number of bird species'>

# %%
# NA practice

# %%
df.plot(x='year', 
        y=['TJE_spring', 'TJE_fall'],
        title = 'Seasonal bird surveys at Tijuana Estuary',
        xlabel='Year',
        ylabel='Number of bird species',        
        color = {'TJE_spring':'#F48FB1',
                 'TJE_fall': '#AB47BC'
                 }
        )
# Out:
# <Axes: title={'center': 'Seasonal bird surveys at Tijuana Estuary'}, xlabel='Year', ylabel='Number of bird species'>

# %%
df.plot(x='year', 
        y=['TJE_spring', 'TJE_fall'],
        title = 'Seasonal bird surveys at Tijuana Estuary',
        xlabel='Year',
        ylabel='Number of bird species',        
        color = {'TJE_spring':'#F48FB1',
                 'TJE_fall': '#AB47BC'
                 },
        subplots=True
        )
# Out:
# array([<Axes: xlabel='Year', ylabel='Number of bird species'>,
#        <Axes: xlabel='Year', ylabel='Number of bird species'>],
#       dtype=object)

# %%
# Set index to year 
# Update index to be the year column
df = df.set_index('year')
df.head()
# Out:
#       CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# year
# 2010        39.0        40.0      50.0        45.0         NaN      61.0
# 2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2012        51.0        43.0      49.0        57.0        58.0      53.0
# 2013        42.0        46.0      38.0        60.0        58.0      62.0
# 2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#       SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# year
# 2010         NaN        75.0      85.0         NaN         NaN      81.0
# 2011        78.0        74.0       NaN        67.0        70.0       NaN
# 2012        71.0        72.0      73.0        70.0        63.0      69.0
# 2013        69.0        70.0      70.0        69.0        74.0      64.0
# 2014        61.0        78.0      71.0        60.0        81.0      62.0

# %%
# Simple plot of Carpinteria Salt Marsh winter surveys
df.plot(y='CSM_winter')
# Out:
# <Axes: xlabel='year'>

# %%
# Reset index to just row number 
df = df.reset_index()
df.head()
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0

# %%
# Check in 
# 1.
df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()

# set index to year 
# retrives all rows columns SDW_winter to TJE fall
# Plot the columns

# 2.This is not modifying df we need inplace = TRUE or have it equal to df

# 3. Run the code and examine the graph. Review the data description. Do 
# we have all the necessary information to make sure it makes sense to 
# directly compare the surveys at these different sites?

#  Sampling was avoided during weather conditions that influence 
# bird behavior, such as: (1) precipitation or heavy fog, (2) winds exceeding 15 mph, and (3) temperatures below 40o F.

# The reference wetlands were chosen to represent relatively undisturbed, 
# natural tidal wetlands within the Southern California Bight. 
# # 
# Surveys were performed annually during two separate months in each of three 
# 
# seasons: winter (January, February), spring (April, May), and fall (October, November). 
# All bird plots were sampled once per day on three consecutive days in each month for a 
# total of 18 surveys per plot per year.
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # Check in
# 1. Without running the code, give a step-by-step breakdown of what this code is doing:
# df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()
#
# 2. Is this code modifying the data frame df? Why or why not?
#
# 3. Run the code and examine the graph. Review the data description. Do we have all the
# necessary information to make sure it makes sense to directly compare the surveys at
# these different sites?

# %% [markdown]
# 1. `df.set_index('year')` set index to year
#
# 2. `.loc[:, SDW_winter':'TJE_fall']`
#  - Select all rows
#  - Select column range specficied
# 3. Plot
# You should facet and have a plot for each season

# %%
df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Method chaining is using lots of periods to string them together

# %% [markdown]
# # Check-in:
#
# Select the bill_length_mm and bill_depth_mm columns in the penguins dataframe and then update the kind parameter to box to make boxplots of the bill length and bill depth.
#
# Create a simple histogram of the flipper length of female gentoo penguins.

# %%
URL = 'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv'
penguins = pd.read_csv(URL)

# %%
penguins[['bill_length_mm', 'bill_depth_mm']].plot(kind = 'box', color = 'hotpink')
# Out:
# <Axes: >

# %%
# Flipper length of female gentoo penguins

female_gentoos = penguins[(penguins['sex'] == 'female') & (penguins['species'] == 'Gentoo')]

#Create a simple histogram of the flipper length of female gentoo penguins.

female_gentoos['flipper_length_mm'].plot(kind = 'hist', 
                                        title = 'Frequency of Flipper Length in Female Gentoo Penguins',
                                        xlabel = 'Flipper Length (mm)',
                                        color = 'hotpink')
# Out:
# <Axes: title={'center': 'Frequency of Flipper Length in Female Gentoo Penguins'}, xlabel='Flipper Length (mm)', ylabel='Frequency'>

# %%
penguins.loc[(penguins['sex'] == 'female') & (penguins['species'] == 'Gentoo'), 'flipper_length_mm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
